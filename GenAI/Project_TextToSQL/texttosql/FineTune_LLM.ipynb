# %%
pip install openai datasets
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import json
import pandas as pd
from openai import OpenAI
from datasets import load_dataset
from pathlib import Path
from google.colab import userdata
import os

# Install required packages
# !pip install openai>=1.0.0 pandas datasets

# Prompt for OpenAI API key
from getpass import getpass
api_key = getpass("Enter your OpenAI API key: ")

# Initialize OpenAI client
client = OpenAI(api_key=api_key)
# Out:
# Enter your OpenAI API key: ··········

# %% [markdown]
# # FINE TUNE THE MODEL

# %%
# Install dependencies (if running in Colab or new env)
# !pip install openai sqlparse

import os
import json
import sqlparse
from openai import OpenAI
from getpass import getpass

# Secure API Key (don't hardcode!)
api_key = os.getenv("OPENAI_API_KEY") or getpass("Enter your OpenAI API key: ")
client = OpenAI(api_key=api_key)

# ------------------ SQL Normalization ------------------
def normalize_sql(query):
    try:
        parsed = sqlparse.parse(query)[0]
        return sqlparse.format(str(parsed), keyword_case='lower', strip_comments=True)
    except Exception:
        return query

# ------------------ Schema Prompt Generation ------------------
def get_schema_prompt(db_id, tables_data):
    for table in tables_data:
        if table['db_id'] == db_id:
            schema_lines = []
            table_names = table["table_names_original"]
            column_names = table["column_names_original"]
            pk = table.get("primary_keys", [])
            fk = table.get("foreign_keys", [])

            table_column_map = {t: [] for t in table_names}
            for t_idx, col_name in column_names:
                if t_idx != -1:
                    table_column_map[table_names[t_idx]].append(col_name)

            for table_name in table_names:
                schema_lines.append(f"Table: {table_name}")
                schema_lines.append(f"Columns: {', '.join(table_column_map[table_name])}")

            if pk:
                pk_str = ", ".join([
                    f"{table_names[column_names[i][0]]}({column_names[i][1]})" for i in pk
                ])
                schema_lines.append(f"Primary Keys: {pk_str}")
            if fk:
                fk_str = []
                for from_idx, to_idx in fk:
                    from_tbl_idx, from_col = column_names[from_idx]
                    to_tbl_idx, to_col = column_names[to_idx]
                    fk_str.append(f"{table_names[from_tbl_idx]}({from_col}) → {table_names[to_tbl_idx]}({to_col})")
                schema_lines.append(f"Foreign Keys: {', '.join(fk_str)}")

            return "\n".join(schema_lines)
    return f"Schema for {db_id} not found."

# ------------------ JSONL Builder ------------------
def prepare_jsonl(train_path, tables_path, output_jsonl):
    with open(train_path, 'r') as f:
        train_data = json.load(f)
    with open(tables_path, 'r') as f:
        tables_data = json.load(f)

    jsonl_data = []
    for example in train_data:
        db_id = example['db_id']
        question = example['question']
        sql = normalize_sql(example['query'])

        schema_str = get_schema_prompt(db_id, tables_data)
        system_prompt = (
            "You are a SQL query generator. Given a natural language question and database schema, "
            "generate the correct SQL query. Only return the SQL query.\n\n"
            f"Database Schema:\n{schema_str}\n"
        )

        jsonl_data.append({
            "messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": question},
                {"role": "assistant", "content": sql}
            ]
        })

    with open(output_jsonl, 'w') as f:
        for entry in jsonl_data:
            json.dump(entry, f)
            f.write('\n')

    print(f"✅ Prepared {len(jsonl_data)} samples → {output_jsonl}")
    return output_jsonl

# ------------------ Fine-tuning Launch ------------------
def launch_finetune(jsonl_path, model="gpt-4o-mini-2024-07-18", n_epochs=4, lr_mult=0.05):
    with open(jsonl_path, 'rb') as f:
        file = client.files.create(file=f, purpose="fine-tune")
    print(f"📤 Uploaded training file: {file.id}")

    job = client.fine_tuning.jobs.create(
        training_file=file.id,
        model=model,
        hyperparameters={
            "n_epochs": n_epochs,
            "learning_rate_multiplier": lr_mult
        }
    )
    print(f"🚀 Fine-tuning started: Job ID = {job.id}")
    print(f"📊 Monitor at: https://platform.openai.com/finetune/{job.id}")
    return job.id

# ------------------ Run Script ------------------
if __name__ == "__main__":
    train_file = "/content/train_spider.json"     # Update if different path
    tables_file = "/content/tables.json"          # Update if different path
    output_jsonl = "/content/spider_finetune.jsonl"

    # Step 1: Prepare dataset
    prepare_jsonl(train_file, tables_file, output_jsonl)

    # Step 2: Fine-tune GPT-4o-mini
    job_id = launch_finetune(output_jsonl)
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.11/dist-packages (0.5.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Enter your OpenAI API key: ··········
# ✅ Prepared 7000 samples → /content/spider_finetune.jsonl
# 📤 Uploaded training file: file-Sxp2BNtpyrRyQgR3AdQEDp
# 🚀 Fine-tuning started: Job ID = ftjob-AmI5FbeFOPSdYwXxt6mtyNiN
# 📊 Monitor at: https://platform.openai.com/finetune/ftjob-AmI5FbeFOPSdYwXxt6mtyNiN

# %%
from openai import OpenAI
from getpass import getpass
client = OpenAI(api_key=getpass("Enter your OpenAI API key: "))
fine_tune_id = ""  # Replace with the ID from the output
status = client.fine_tuning.jobs.retrieve(fine_tune_id)
print(status)
# Out:
# Enter your OpenAI API key: ··········
# FineTuningJob(id='ftjob-AmI5FbeFOPSdYwXxt6mtyNiN', created_at=1746745355, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-mini-2024-07-18:sjsu::BV5M5MaD', finished_at=1746748451, hyperparameters=Hyperparameters(batch_size=18, learning_rate_multiplier=0.05, n_epochs=4), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-M0bndO6DFw6B9DjLFKHYmAl3', result_files=['file-XhBJMVd8ZUN1VNxYjufWyw'], seed=2099147120, status='succeeded', trained_tokens=9396732, training_file='file-Sxp2BNtpyrRyQgR3AdQEDp', validation_file=None, estimated_finish=None, integrations=[], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size=18, learning_rate_multiplier=0.05, n_epochs=4)), type='supervised'), user_provided_suffix=None, usage_metrics=None, shared_with_openai=False, eval_id=None)

# %% [markdown]
# # Inference

# %%
from openai import OpenAI
client = OpenAI(api_key="")
response = client.chat.completions.create(
    model="ft:gpt-4o-mini-2024-07-18:sjsu::BV5M5MaD",
    messages=[
        {"role": "system", "content": "You are a SQL query generator. Given a natural language question and a database schema, generate the correct SQL query. The schema is provided below:\n\nDatabase: department\nSchema details are contextually inferred from the question.\n\nReturn only the SQL query without any explanation."},
        {"role": "user", "content": "Find all courses offered by the Computer Science department."}
    ]
)
print(response.choices[0].message.content)
# Out:
# select course from department where department_name  =  'Computer Science'

# %% [markdown]
# # Evaluate pretrained model

# %%
# !pip install sqlparse
# Out:
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.11/dist-packages (0.5.3)

# %%
pip install datasets openai
# Out:
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 14.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from sqlparse.tokens import Keyword, Name, String
from getpass import getpass
import json
import pandas as pd
from openai import OpenAI
from datasets import load_dataset

# %%
FINE_TUNE_ID = "ftjob-M8mm3GxzFuIGqxzU82YRUFZh"
FINE_TUNED_MODEL = "ft:gpt-4o-mini-2024-07-18:sjsu::BV5M5MaD"

# Load Spider validation dataset
def load_spider_validation():
    """Load Spider validation dataset from Hugging Face."""
    dataset = load_dataset("spider")
    return dataset['validation']

def get_schema_prompt(db_id):
    """Generate schema prompt using tables.json (Spider format)."""
    try:
        with open('/content/tables.json', 'r') as f:
            tables = json.load(f)
        for table in tables:
            if table['db_id'] == db_id:
                table_names = table["table_names_original"]
                column_names = table["column_names_original"]

                # Map each table name to its columns
                table_column_map = {t: [] for t in table_names}
                for table_idx, col_name in column_names:
                    if table_idx != -1:
                        table_column_map[table_names[table_idx]].append(col_name)

                # Construct schema string
                schema_lines = []
                for table_name in table_names:
                    schema_lines.append(f"Table: {table_name}")
                    schema_lines.append("Columns: " + ", ".join(table_column_map[table_name]))

                return "\n".join(schema_lines)

        return f"Database: {db_id}\nSchema not found in tables.json"
    except Exception as e:
        return f"Error loading schema for {db_id}: {e}"


import sqlparse
import pandas as pd
from sqlparse.tokens import Keyword, Name, String, Number, Punctuation, Operator

def normalize_sql(query):
    try:
        parsed = sqlparse.parse(query)[0]
        normalized_tokens = []

        for token in parsed.flatten():  # Flatten all nested tokens
            if token.ttype in Keyword or token.ttype in Name:
                normalized_tokens.append(token.value.lower())
            elif token.ttype in (String.Single, String.Symbol, Number.Integer, Number.Float):
                normalized_tokens.append(token.value)
            elif token.ttype in (Punctuation, Operator):
                normalized_tokens.append(token.value)
            else:
                normalized_tokens.append(token.value)

        # Join and normalize spacing and remove trailing semicolon
        normalized = ' '.join(''.join(normalized_tokens).split())
        return normalized.strip().rstrip(";")
    except Exception as e:
        print(f"Error normalizing SQL: {e}")
        return query.strip().rstrip(";").lower()


def evaluate_model(validation_data, model_id, max_examples=None):
    """Evaluate the fine-tuned model on the validation set with case-insensitive matching."""
    exact_match_count = 0
    total_examples = 0
    results = []

    for item in validation_data:
        if max_examples and total_examples >= max_examples:
            break

        db_id = item['db_id']
        question = item['question']
        ground_truth_sql = item['query']

        # Prepare system prompt
        schema_prompt = get_schema_prompt(db_id)
        system_prompt = (
            "You are a SQL query generator. Given a natural language question and a database schema, "
            "generate the correct SQL query. The schema is provided below:\n\n"
            f"{schema_prompt}\n\n"
            "Return only the SQL query without any explanation."
        )

        # Generate predicted SQL query
        try:
            response = client.chat.completions.create(
                model=model_id,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": question}
                ],
                max_tokens=200,
                temperature=0.0
            )
            predicted_sql = response.choices[0].message.content.strip()
        except Exception as e:
            print(f"Error generating SQL for question '{question}': {e}")
            predicted_sql = ""

        # Normalize SQL queries for comparison
        normalized_predicted = normalize_sql(predicted_sql) if predicted_sql else ""
        normalized_ground_truth = normalize_sql(ground_truth_sql)

        # Check case-insensitive exact match
        normalized_predicted = normalize_sql(predicted_sql) if predicted_sql else ""
        normalized_ground_truth = normalize_sql(ground_truth_sql)

        is_exact_match = normalized_predicted == normalized_ground_truth


        if is_exact_match:
            exact_match_count += 1
        else:
            # Log mismatch for debugging
            print(f"Mismatch for question '{question}':")
            print(f"Ground Truth: {normalized_ground_truth}")
            print(f"Predicted: {normalized_predicted}")

        # Store results
        results.append({
            "question": question,
            "ground_truth_sql": ground_truth_sql,
            "predicted_sql": predicted_sql,
            "normalized_ground_truth": normalized_ground_truth,
            "normalized_predicted": normalized_predicted,
            "is_exact_match": is_exact_match,
            "schema_prompt": schema_prompt
        })

        total_examples += 1
        if total_examples % 10 == 0:
            print(f"Processed {total_examples} examples...")

    # Calculate accuracy
    exact_match_accuracy = exact_match_count / total_examples if total_examples > 0 else 0
    print(f"\nEvaluation complete!")
    print(f"Total examples: {total_examples}")
    #print(f"Case-insensitive exact match accuracy: {exact_match_accuracy:.4f} ({exact_match_count}/{total_examples})")

    # Save results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv("/content/evaluation_results_FINETUNED.csv", index=False)
    print("Results saved to /content/evaluation_results_FINETUNED.csv")

    print(f"Correct predictions after normalization: {exact_match_count}/{total_examples}")
    print(f"Accuracy: {exact_match_accuracy:.2%}")


    return exact_match_accuracy, results

def main():
    print("Ensure tables.json is uploaded for accurate schema details.")
    print("Loading Spider validation dataset...")
    validation_data = load_spider_validation()

    print(f"Evaluating model {FINE_TUNED_MODEL}...")
    # Limit to 100 examples for testing
    exact_match_accuracy, results = evaluate_model(validation_data, FINE_TUNED_MODEL, max_examples=100)

    # Download results file
    print("Downloading evaluation results...")

if __name__ == "__main__":
    main()
# Out:
# Ensure tables.json is uploaded for accurate schema details.
# Loading Spider validation dataset...
# Evaluating model ft:gpt-4o-mini-2024-07-18:sjsu::BV5M5MaD...
# Mismatch for question 'What is the average, minimum, and maximum age of all singers from France?':
# Ground Truth: select avg(age) , min(age) , max(age) from singer where country = 'France'
# Predicted: select avg(age) , min(age) , max(age) from singer where country = "France"
# Mismatch for question 'What is the average, minimum, and maximum age for all French singers?':
# Ground Truth: select avg(age) , min(age) , max(age) from singer where country = 'France'
# Predicted: select avg(age) , min(age) , max(age) from singer where nationality = 'French'
# Mismatch for question 'Show the name and the release year of the song by the youngest singer.':
# Ground Truth: select song_name , song_release_year from singer order by age limit 1
# Predicted: select name , release_year from song order by year desc limit 1
# Mismatch for question 'What are the names and release years for all the songs of the youngest singer?':
# Ground Truth: select song_name , song_release_year from singer order by age limit 1
# Predicted: select name , release_year from singer join song on singer.id = song.singer_id order by birth_date desc limit 1
# Processed 10 examples...
# Mismatch for question 'How many singers are from each country?':
# Ground Truth: select country , count(*) from singer group by country
# Predicted: select count(*) , country from singer group by country
# Mismatch for question 'List all song names by singers above the average age.':
# Ground Truth: select song_name from singer where age > (select avg(age) from singer)
# Predicted: select song_name from concert_singer where singer_age > (select avg(singer_age) from concert_singer)
# Mismatch for question 'What are the locations and names of all stations with capacity between 5000 and 10000?':
# Ground Truth: select location , name from stadium where capacity between 5000 and 10000
# Predicted: select location , name from station where capacity between 5000 and 10000
# Mismatch for question 'What is the maximum capacity and the average of all stadiums ?':
# Ground Truth: select max(capacity), average from stadium
# Predicted: select max(capacity) , avg(capacity) from stadium
# Mismatch for question 'What is the name and capacity for the stadium with highest average attendance?':
# Ground Truth: select name , capacity from stadium order by average desc limit 1
# Predicted: select name , capacity from stadium order by average_attendance desc limit 1
# Mismatch for question 'What is the name and capacity for the stadium with the highest average attendance?':
# Ground Truth: select name , capacity from stadium order by average desc limit 1
# Predicted: select name , capacity from stadium order by average_attendance desc limit 1
# Processed 20 examples...
# Mismatch for question 'Show the stadium name and the number of concerts in each stadium.':
# Ground Truth: select t2.name , count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
# Predicted: select stadium_name , count(*) from concert group by stadium_name
# Mismatch for question 'For each stadium, how many concerts play there?':
# Ground Truth: select t2.name , count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
# Predicted: select stadium , count(*) from concert group by stadium
# Mismatch for question 'Show the stadium name and capacity with most number of concerts in year 2014 or after.':
# Ground Truth: select t2.name , t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
# Predicted: select stadium_name , capacity from concert_singer where year >= 2014 group by stadium_name order by count(*) desc limit 1
# Mismatch for question 'What is the name and capacity of the stadium with the most concerts after 2013 ?':
# Ground Truth: select t2.name , t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
# Predicted: select name , capacity from stadium order by concerts desc limit 1
# Mismatch for question 'Show the stadium names without any concert.':
# Ground Truth: select name from stadium where stadium_id not in (select stadium_id from concert)
# Predicted: select name from stadium where id not in (select stadium_id from concert)
# Mismatch for question 'What are the names of the stadiums without any concerts?':
# Ground Truth: select name from stadium where stadium_id not in (select stadium_id from concert)
# Predicted: select name from stadium where id not in (select stadium_id from concert)
# Processed 30 examples...
# Mismatch for question 'Show countries where a singer above age 40 and a singer below 30 are from.':
# Ground Truth: select country from singer where age > 40 intersect select country from singer where age < 30
# Predicted: select country from singer where age between 30 and 40 intersect select country from singer where age between 20 and 30
# Mismatch for question 'Show names for all stadiums except for stadiums having a concert in year 2014.':
# Ground Truth: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
# Predicted: select name from stadium where id not in (select stadium_id from concert where year = 2014)
# Mismatch for question 'What are the names of all stadiums that did not have a concert in 2014?':
# Ground Truth: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
# Predicted: select name from stadium where id not in (select stadium_id from concert where year = 2014)
# Mismatch for question 'Show the name and theme for all concerts and the number of singers in each concert.':
# Ground Truth: select t2.concert_name , t2.theme , count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
# Predicted: select name , theme , count(*) from concert_singer group by name , theme
# Mismatch for question 'What are the names , themes , and number of singers for every concert ?':
# Ground Truth: select t2.concert_name , t2.theme , count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
# Predicted: select name , theme , count(*) from concert_singer group by name , theme
# Mismatch for question 'List singer names and number of concerts for each singer.':
# Ground Truth: select t2.name , count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
# Predicted: select singer_name , count(*) from concert_singer group by singer_name
# Mismatch for question 'What are the names of the singers and number of concerts for each person?':
# Ground Truth: select t2.name , count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
# Predicted: select singer , count(*) from concert_singer group by singer
# Mismatch for question 'List all singer names in concerts in year 2014.':
# Ground Truth: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
# Predicted: select singer_name from concert_singer where concert_year = 2014
# Mismatch for question 'What are the names of the singers who performed in a concert in 2014?':
# Ground Truth: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
# Predicted: select singer_name from concert_singer where concert_year = 2014
# Mismatch for question 'what is the name and nation of the singer who have a song having 'Hey' in its name?':
# Ground Truth: select name , country from singer where song_name LIKE '%Hey%'
# Predicted: select distinct t1.name , t1.nation from singer as t1 join song as t2 on t1.id = t2.singer_id where t2.name like '%Hey%'
# Processed 40 examples...
# Mismatch for question 'What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?':
# Ground Truth: select name , country from singer where song_name LIKE '%Hey%'
# Predicted: select name , country from singer where id in (select singer_id from song where title like '%Hey%')
# Mismatch for question 'Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.':
# Ground Truth: select t2.name , t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name , t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
# Predicted: select distinct stadium_name , stadium_location from concert_singer where year = 2014 intersect select distinct stadium_name , stadium_location from concert_singer where year = 2015
# Mismatch for question 'What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?':
# Ground Truth: select t2.name , t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name , t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
# Predicted: select distinct stadium_name , stadium_location from concert_singer where concert_year = 2014 intersect select distinct stadium_name , stadium_location from concert_singer where concert_year = 2015
# Mismatch for question 'What are the number of concerts that occurred in the stadium with the largest capacity ?':
# Ground Truth: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
# Predicted: select count(*) from concert_singer where stadium_capacity = (select max(stadium_capacity) from concert_singer)
# Mismatch for question 'Find the weight of the youngest dog.':
# Ground Truth: select weight from pets order by pet_age limit 1
# Predicted: select weight from pets where type = 'dog' order by age limit 1
# Mismatch for question 'How much does the youngest dog weigh?':
# Ground Truth: select weight from pets order by pet_age limit 1
# Predicted: select weight from pets where type = 'dog' order by age asc limit 1
# Mismatch for question 'Find the maximum weight for each type of pet. List the maximum weight and pet type.':
# Ground Truth: select max(weight) , pettype from pets group by pettype
# Predicted: select max(weight) , type from pets group by type
# Processed 50 examples...
# Mismatch for question 'List the maximum weight and type for each type of pet.':
# Ground Truth: select max(weight) , pettype from pets group by pettype
# Predicted: select max(weight) , type from pets group by type
# Mismatch for question 'Find number of pets owned by students who are older than 20.':
# Ground Truth: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
# Predicted: select count(*) from pets_1 where owner_id in (select id from students where age > 20)
# Mismatch for question 'How many pets are owned by students that have an age greater than 20?':
# Ground Truth: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
# Predicted: select count(*) from pets_1 where owner_id in (select id from students where age > 20)
# Mismatch for question 'Find the number of dog pets that are raised by female students (with sex F).':
# Ground Truth: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'F' and t3.pettype = 'dog'
# Predicted: select count(*) from pets_1 where type = 'dog' and owner_id in (select id from students_1 where sex = 'F')
# Mismatch for question 'How many dog pets are raised by female students?':
# Ground Truth: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'F' and t3.pettype = 'dog'
# Predicted: select count(*) from pets_1 where type = "dog" and gender = "female"
# Mismatch for question 'Find the number of distinct type of pets.':
# Ground Truth: select count(distinct pettype) from pets
# Predicted: select count(distinct type) from pets
# Mismatch for question 'How many different types of pet are there?':
# Ground Truth: select count(distinct pettype) from pets
# Predicted: select count(distinct type) from pets
# Mismatch for question 'Find the first name of students who have cat or dog pet.':
# Ground Truth: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
# Predicted: select first_name from students where id in (select student_id from pets where type = 'cat' or type = 'dog')
# Mismatch for question 'What are the first names of every student who has a cat or dog as a pet?':
# Ground Truth: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
# Predicted: select first_name from students where id in (select student_id from pets where type = 'cat' or type = 'dog')
# Mismatch for question 'Find the first name of students who have both cat and dog pets .':
# Ground Truth: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
# Predicted: select first_name from students where id in (select student_id from pets where type = 'cat') intersect select first_name from students where id in (select student_id from pets where type = 'dog')
# Processed 60 examples...
# Mismatch for question 'What are the students' first names who have both cats and dogs as pets?':
# Ground Truth: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
# Predicted: select first_name from students where id in (select student_id from pets where type = 'cat') intersect select first_name from students where id in (select student_id from pets where type = 'dog')
# Mismatch for question 'Find the major and age of students who do not have a cat pet.':
# Ground Truth: select major , age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
# Predicted: select major , age from students where id not in (select student_id from pets where type = 'cat')
# Mismatch for question 'What major is every student who does not own a cat as a pet, and also how old are they?':
# Ground Truth: select major , age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
# Predicted: select major , age from students where id not in (select student_id from pets where type = 'cat')
# Mismatch for question 'Find the id of students who do not have a cat pet.':
# Ground Truth: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
# Predicted: select id from students where id not in (select student_id from pets where type = 'cat')
# Mismatch for question 'What are the ids of the students who do not own cats as pets?':
# Ground Truth: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
# Predicted: select id from students where id not in (select student_id from pets where type = 'cat')
# Mismatch for question 'Find the first name and age of students who have a dog but do not have a cat as a pet.':
# Ground Truth: select t1.fname , t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
# Predicted: select first_name , age from students where id in (select student_id from pets where type = "dog") and id not in (select student_id from pets where type = "cat")
# Mismatch for question 'What is the first name of every student who has a dog but does not have a cat?':
# Ground Truth: select t1.fname , t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
# Predicted: select first_name from pets_1 where pet_type = 'dog' except select first_name from pets_1 where pet_type = 'cat'
# Mismatch for question 'Find the type and weight of the youngest pet.':
# Ground Truth: select pettype , weight from pets order by pet_age limit 1
# Predicted: select type , weight from pets order by age limit 1
# Mismatch for question 'What type of pet is the youngest animal, and how much does it weigh?':
# Ground Truth: select pettype , weight from pets order by pet_age limit 1
# Predicted: select type , weight from pets order by age limit 1
# Mismatch for question 'Find the id and weight of all pets whose age is older than 1.':
# Ground Truth: select petid , weight from pets where pet_age > 1
# Predicted: select id , weight from pets where age > 1
# Processed 70 examples...
# Mismatch for question 'What is the id and weight of every pet who is older than 1?':
# Ground Truth: select petid , weight from pets where pet_age > 1
# Predicted: select id , weight from pets where age > 1
# Mismatch for question 'Find the average and maximum age for each type of pet.':
# Ground Truth: select avg(pet_age) , max(pet_age) , pettype from pets group by pettype
# Predicted: select type , avg(age) , max(age) from pets group by type
# Mismatch for question 'What is the average and maximum age for each pet type?':
# Ground Truth: select avg(pet_age) , max(pet_age) , pettype from pets group by pettype
# Predicted: select type , avg(age) , max(age) from pets group by type
# Mismatch for question 'Find the average weight for each pet type.':
# Ground Truth: select avg(weight) , pettype from pets group by pettype
# Predicted: select type , avg(weight) from pets group by type
# Mismatch for question 'What is the average weight for each type of pet?':
# Ground Truth: select avg(weight) , pettype from pets group by pettype
# Predicted: select type , avg(weight) from pets group by type
# Mismatch for question 'Find the first name and age of students who have a pet.':
# Ground Truth: select distinct t1.fname , t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
# Predicted: select first_name , age from students where id in (select student_id from pets)
# Mismatch for question 'What are the different first names and ages of the students who do have pets?':
# Ground Truth: select distinct t1.fname , t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
# Predicted: select first_name , age from students where has_pet = 1
# Mismatch for question 'Find the id of the pet owned by student whose last name is ‘Smith’.':
# Ground Truth: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'Smith'
# Predicted: select pet_id from pets where owner_id in (select id from students where last_name = 'Smith')
# Mismatch for question 'What is the id of the pet owned by the student whose last name is 'Smith'?':
# Ground Truth: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'Smith'
# Predicted: select pet_id from pets where owner_id in (select id from students where last_name = 'Smith')
# Mismatch for question 'Find the number of pets for each student who has any pet and student id.':
# Ground Truth: select count(*) , t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
# Predicted: select student_id , count(*) from pets group by student_id
# Processed 80 examples...
# Mismatch for question 'For students who have pets , how many pets does each student have ? list their ids instead of names .':
# Ground Truth: select count(*) , t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
# Predicted: select student_id , count(*) from pets group by student_id
# Mismatch for question 'Find the first name and gender of student who have more than one pet.':
# Ground Truth: select t1.fname , t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
# Predicted: select first_name , gender from students where student_id in (select student_id from pets group by student_id having count(*) > 1)
# Mismatch for question 'What is the first name and gender of the all the students who have more than one pet?':
# Ground Truth: select t1.fname , t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
# Predicted: select first_name , gender from students where student_id in (select student_id from pets group by student_id having count(*) > 1)
# Mismatch for question 'Find the last name of the student who has a cat that is age 3.':
# Ground Truth: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
# Predicted: select last_name from students where id in (select student_id from pets where age = 3 and type = 'cat')
# Mismatch for question 'What is the last name of the student who has a cat that is 3 years old?':
# Ground Truth: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
# Predicted: select last_name from students where id in (select student_id from pets where pet_type = 'cat' and age = 3)
# Mismatch for question 'Find the average age of students who do not have any pet .':
# Ground Truth: select avg(age) from student where stuid not in (select stuid from has_pet)
# Predicted: select avg(age) from students where id not in (select student_id from pets)
# Mismatch for question 'What is the average age for all students who do not own any pets ?':
# Ground Truth: select avg(age) from student where stuid not in (select stuid from has_pet)
# Predicted: select avg(age) from students where id not in (select student_id from pets)
# Mismatch for question 'How many continents are there?':
# Ground Truth: select count(*) from continents
# Predicted: select count(distinct continent) from countries
# Mismatch for question 'What is the number of continents?':
# Ground Truth: select count(*) from continents
# Predicted: select count(distinct continent) from countries
# Mismatch for question 'How many countries does each continent have? List the continent id, continent name and the number of countries.':
# Ground Truth: select t1.contid , t1.continent , count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
# Predicted: select continent_id , continent_name , count(*) from countries group by continent_id
# Processed 90 examples...
# Mismatch for question 'For each continent, list its id, name, and how many countries it has?':
# Ground Truth: select t1.contid , t1.continent , count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
# Predicted: select continent_id , continent_name , count(*) from continent group by continent_id
# Mismatch for question 'How many countries are listed?':
# Ground Truth: select count(*) from countries
# Predicted: select count(distinct country) from country
# Mismatch for question 'How many countries exist?':
# Ground Truth: select count(*) from countries
# Predicted: select count(distinct country) from country
# Mismatch for question 'How many models does each car maker produce? List maker full name, id and the number.':
# Ground Truth: select t1.fullname , t1.id , count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
# Predicted: select maker , count(*) from car group by maker
# Mismatch for question 'What is the full name of each car maker, along with its id and how many models it produces?':
# Ground Truth: select t1.fullname , t1.id , count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
# Predicted: select maker , count(*) , id from car group by maker
# Mismatch for question 'Which model of the car has the minimum horsepower?':
# Ground Truth: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
# Predicted: select model from car order by horsepower asc limit 1
# Mismatch for question 'What is the model of the car with the smallest amount of horsepower?':
# Ground Truth: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
# Predicted: select model from cars order by horsepower limit 1
# Mismatch for question 'Find the model of the car whose weight is below the average weight.':
# Ground Truth: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
# Predicted: select model from car where weight < (select avg(weight) from car)
# Mismatch for question 'What is the model for the car with a weight smaller than the average?':
# Ground Truth: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
# Predicted: select model from car where weight < (select avg(weight) from car)
# Mismatch for question 'Find the name of the makers that produced some cars in the year of 1970?':
# Ground Truth: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
# Predicted: select maker from car where year = 1970
# Processed 100 examples...
#
# Evaluation complete!
# Total examples: 100
# Results saved to /content/evaluation_results_FINETUNED.csv
# Correct predictions after normalization: 17/100
# Accuracy: 17.00%
# Downloading evaluation results...

# %%
import json
import pandas as pd
from openai import OpenAI
from datasets import load_dataset
from google.colab import files
import sqlparse
from sqlparse.tokens import Keyword, Name, String
from getpass import getpass

# Prompt for OpenAI API key
api_key = getpass("Enter your OpenAI API key: ")

# Initialize OpenAI client
client = OpenAI(api_key=api_key)

# Base model ID
BASE_MODEL = "gpt-4o-mini-2024-07-18"

# Load Spider validation dataset
def load_spider_validation():
    """Load Spider validation dataset from Hugging Face."""
    dataset = load_dataset("spider")
    return dataset['validation']

def get_schema_prompt(db_id):
    """Generate schema prompt using tables.json (correct Spider format)."""
    try:
        with open('/content/tables.json', 'r') as f:
            tables = json.load(f)
        for table in tables:
            if table['db_id'] == db_id:
                table_names = table['table_names_original']
                column_names = table['column_names_original']

                table_column_map = {t: [] for t in table_names}
                for table_idx, col_name in column_names:
                    if table_idx != -1:  # -1 means it's "*"
                        table_column_map[table_names[table_idx]].append(col_name)

                schema_lines = []
                for table_name in table_names:
                    schema_lines.append(f"Table: {table_name}")
                    schema_lines.append("Columns: " + ", ".join(table_column_map[table_name]))

                return "\n".join(schema_lines)

        return f"Database: {db_id}\nSchema not found."
    except Exception as e:
        return f"Error loading schema for {db_id}: {e}"


def normalize_sql(query):
    """Normalize SQL query for case-insensitive comparison, removing semicolons and AS aliases."""
    try:
        # Parse the SQL query into tokens
        parsed = sqlparse.parse(query)[0]
        normalized_tokens = []
        skip_next = False

        for i, token in enumerate(parsed.tokens):
            if skip_next:
                skip_next = False
                continue
            if token.value.lower() == 'as' and i + 1 < len(parsed.tokens):
                # Skip 'AS' and the next token (alias) for simple queries
                skip_next = True
                continue
            if token.ttype in (Keyword, Keyword.DML, Keyword.DDL, Keyword.CTE):
                # Convert keywords (e.g., SELECT, WHERE) to lowercase
                normalized_tokens.append(token.value.lower())
            elif token.ttype in (Name, Name.Builtin):
                # Convert identifiers (e.g., table/column names) to lowercase
                normalized_tokens.append(token.value.lower())
            elif token.ttype is String.Single or token.ttype is String.Symbol:
                # Preserve string literals (e.g., 'Computer Science') unchanged
                normalized_tokens.append(token.value)
            elif token.value == ';':
                # Skip semicolons
                continue
            else:
                # Keep other tokens (e.g., operators, numbers, punctuation) unchanged
                normalized_tokens.append(token.value)

        # Join tokens and clean up extra whitespace
        normalized = ' '.join(''.join(normalized_tokens).split())
        return normalized
    except Exception as e:
        print(f"Error normalizing SQL '{query}': {e}")
        return query  # Return original if parsing fails

def evaluate_model(validation_data, model_id, max_examples=None):
    """Evaluate the model on the validation set."""
    exact_match_count = 0
    total_examples = 0
    results = []

    for item in validation_data:
        if max_examples and total_examples >= max_examples:
            break

        db_id = item['db_id']
        question = item['question']
        ground_truth_sql = item['query']

        # Prepare system prompt
        try:
            schema_prompt = get_schema_prompt(db_id)
        except FileNotFoundError as e:
            print(e)
            return 0, []

        system_prompt = (
            "You are a SQL query generator. Given a natural language question and a database schema, "
            "generate the correct SQL query. The schema is provided below:\n\n"
            f"{schema_prompt}\n\n"
            "Return only the SQL query without any explanation."
        )

        # Generate predicted SQL query
        try:
            response = client.chat.completions.create(
                model=model_id,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": question}
                ],
                max_tokens=200,
                temperature=0.0
            )
            predicted_sql = response.choices[0].message.content.strip()
        except Exception as e:
            print(f"Error generating SQL for question '{question}': {e}")
            predicted_sql = ""

        # Normalize SQL queries for comparison
        normalized_predicted = normalize_sql(predicted_sql) if predicted_sql else ""
        normalized_ground_truth = normalize_sql(ground_truth_sql)

        # Check exact match
        is_exact_match = normalized_predicted == normalized_ground_truth
        if is_exact_match:
            exact_match_count += 1

        # Store results
        results.append({
            "question": question,
            "ground_truth_sql": ground_truth_sql,
            "predicted_sql": predicted_sql,
            "normalized_ground_truth": normalized_ground_truth,
            "normalized_predicted": normalized_predicted,
            "is_exact_match": is_exact_match,
            "schema_prompt": schema_prompt
        })

        total_examples += 1
        if total_examples % 10 == 0:
            print(f"Processed {total_examples} examples...")

    # Calculate accuracy
    exact_match_accuracy = exact_match_count / total_examples if total_examples > 0 else 0
    print(f"\nEvaluation complete!")
    print(f"Total examples: {total_examples}")
    print(f"Exact match accuracy: {exact_match_accuracy:.4f} ({exact_match_count}/{total_examples})")

    # Save results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv("/content/base_evaluation_results_basemodel.csv", index=False)
    print("Results saved to /content/base_evaluation_results_basemodel.csv")

    return exact_match_accuracy, results

def main():
    print("Ensure tables.json is uploaded to /content/tables.json for accurate schema details.")
    try:
        print("Loading Spider validation dataset...")
        validation_data = load_spider_validation()

        print(f"Evaluating base model {BASE_MODEL}...")
        # Limit to 100 examples for testing
        exact_match_accuracy, results = evaluate_model(validation_data, BASE_MODEL, max_examples=100)

        # Download results file
        print("Downloading evaluation results...")
    except Exception as e:
        print(f"Error during evaluation: {e}")

if __name__ == "__main__":
    main()
# Out:
# Enter your OpenAI API key: ··········
# Ensure tables.json is uploaded to /content/tables.json for accurate schema details.
# Loading Spider validation dataset...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.51k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/831k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/126k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1034 [00:00<?, ? examples/s]
# Evaluating base model gpt-4o-mini-2024-07-18...
# Processed 10 examples...
# Processed 20 examples...
# Processed 30 examples...
# Processed 40 examples...
# Processed 50 examples...
# Processed 60 examples...
# Processed 70 examples...
# Processed 80 examples...
# Processed 90 examples...
# Processed 100 examples...
#
# Evaluation complete!
# Total examples: 100
# Exact match accuracy: 0.0000 (0/100)
# Results saved to /content/base_evaluation_results_basemodel.csv
# Downloading evaluation results...


#   inflating: /content/database/__MACOSX/spider_data/test_database/._browser_web
#    creating: /content/database/spider_data/test_database/musical/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._musical
#    creating: /content/database/spider_data/test_database/country_language/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._country_language
#    creating: /content/database/spider_data/test_database/farm/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._farm
#    creating: /content/database/spider_data/test_database/voter_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._voter_1
#    creating: /content/database/spider_data/test_database/game_injury/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._game_injury
#    creating: /content/database/spider_data/test_database/hospital_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._hospital_1
#    creating: /content/database/spider_data/test_database/manufacturer/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._manufacturer
#    creating: /content/database/spider_data/test_database/station_weather/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._station_weather
#    creating: /content/database/spider_data/test_database/perpetrator/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._perpetrator
#    creating: /content/database/spider_data/test_database/soccer_3/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._soccer_3
#    creating: /content/database/spider_data/test_database/storm_record/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._storm_record
#    creating: /content/database/spider_data/test_database/flight_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._flight_1
#    creating: /content/database/spider_data/test_database/manufactory_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._manufactory_1
#    creating: /content/database/spider_data/test_database/cre_Theme_park/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Theme_park
#    creating: /content/database/spider_data/test_database/museum_visit/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._museum_visit
#    creating: /content/database/spider_data/test_database/race_track/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._race_track
#    creating: /content/database/spider_data/test_database/soccer_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._soccer_2
#    creating: /content/database/spider_data/test_database/bike_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._bike_1
#    creating: /content/database/spider_data/test_database/bbc_channels/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._bbc_channels
#    creating: /content/database/spider_data/test_database/pilot_record/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._pilot_record
#    creating: /content/database/spider_data/test_database/customers_and_invoices/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customers_and_invoices
#    creating: /content/database/spider_data/test_database/boat_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._boat_1
#    creating: /content/database/spider_data/test_database/department_management/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._department_management
#    creating: /content/database/spider_data/test_database/news_report/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._news_report
#    creating: /content/database/spider_data/test_database/cre_Doc_and_collections/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Doc_and_collections
#    creating: /content/database/spider_data/test_database/government_shift/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._government_shift
#    creating: /content/database/spider_data/test_database/tvshow/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._tvshow
#    creating: /content/database/spider_data/test_database/music_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._music_1
#    creating: /content/database/spider_data/test_database/store_product/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._store_product
#    creating: /content/database/spider_data/test_database/region_building/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._region_building
#    creating: /content/database/spider_data/test_database/party_host/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._party_host
#    creating: /content/database/spider_data/test_database/ship_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._ship_1
#    creating: /content/database/spider_data/test_database/solvency_ii/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._solvency_ii
#    creating: /content/database/spider_data/test_database/products_gen_characteristics/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._products_gen_characteristics
#    creating: /content/database/spider_data/test_database/dog_kennels/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._dog_kennels
#    creating: /content/database/spider_data/test_database/local_govt_and_lot/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._local_govt_and_lot
#    creating: /content/database/spider_data/test_database/conference/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._conference
#    creating: /content/database/spider_data/test_database/video_game/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._video_game
#    creating: /content/database/spider_data/test_database/culture_company/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._culture_company
#    creating: /content/database/spider_data/test_database/aircraft/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._aircraft
#    creating: /content/database/spider_data/test_database/book_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._book_1
#    creating: /content/database/spider_data/test_database/wta_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._wta_1
#    creating: /content/database/spider_data/test_database/cinema/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cinema
#    creating: /content/database/spider_data/test_database/e_commerce/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._e_commerce
#    creating: /content/database/spider_data/test_database/formula_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._formula_1
#    creating: /content/database/spider_data/test_database/wine_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._wine_1
#    creating: /content/database/spider_data/test_database/gas_company/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._gas_company
#    creating: /content/database/spider_data/test_database/district_spokesman/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._district_spokesman
#    creating: /content/database/spider_data/test_database/customers_and_orders/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customers_and_orders
#    creating: /content/database/spider_data/test_database/network_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._network_2
#    creating: /content/database/spider_data/test_database/match_season/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._match_season
#    creating: /content/database/spider_data/test_database/phone_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._phone_1
#    creating: /content/database/spider_data/test_database/car_road_race/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._car_road_race
#    creating: /content/database/spider_data/test_database/pets_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._pets_1
#    creating: /content/database/spider_data/test_database/tracking_grants_for_research/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._tracking_grants_for_research
#    creating: /content/database/spider_data/test_database/party_people/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._party_people
#    creating: /content/database/spider_data/test_database/hr_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._hr_1
#    creating: /content/database/spider_data/test_database/pilot_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._pilot_1
#    creating: /content/database/spider_data/test_database/scientist_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._scientist_1
#    creating: /content/database/spider_data/test_database/college_3/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._college_3
#    creating: /content/database/spider_data/test_database/cre_Doc_Template_Mgt/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Doc_Template_Mgt
#    creating: /content/database/spider_data/test_database/restaurants/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._restaurants
#    creating: /content/database/spider_data/test_database/program_share/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._program_share
#    creating: /content/database/spider_data/test_database/advertising_agencies/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._advertising_agencies
#    creating: /content/database/spider_data/test_database/college_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._college_2
#    creating: /content/database/spider_data/test_database/course_teach/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._course_teach
#    creating: /content/database/spider_data/test_database/candidate_poll/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._candidate_poll
#    creating: /content/database/spider_data/test_database/cre_Doc_Control_Systems/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Doc_Control_Systems
#    creating: /content/database/spider_data/test_database/wedding/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._wedding
#    creating: /content/database/spider_data/test_database/cre_Doc_Workflow/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Doc_Workflow
#    creating: /content/database/spider_data/test_database/car_racing/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._car_racing
#    creating: /content/database/spider_data/test_database/yelp/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._yelp
#    creating: /content/database/spider_data/test_database/document_management/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._document_management
#    creating: /content/database/spider_data/test_database/aan_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._aan_1
#    creating: /content/database/spider_data/test_database/loan_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._loan_1
#    creating: /content/database/spider_data/test_database/railway/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._railway
#    creating: /content/database/spider_data/test_database/geo/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._geo
#    creating: /content/database/spider_data/test_database/restaurant_bills/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._restaurant_bills
#    creating: /content/database/spider_data/test_database/sakila_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._sakila_1
#    creating: /content/database/spider_data/test_database/headphone_store/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._headphone_store
#    creating: /content/database/spider_data/test_database/movie_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._movie_1
#    creating: /content/database/spider_data/test_database/flight_company/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._flight_company
#    creating: /content/database/spider_data/test_database/csu_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._csu_1
#    creating: /content/database/spider_data/test_database/company_employee/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._company_employee
#    creating: /content/database/spider_data/test_database/orchestra/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._orchestra
#    creating: /content/database/spider_data/test_database/car_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._car_1
#    creating: /content/database/spider_data/test_database/vehicle_driver/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._vehicle_driver
#    creating: /content/database/spider_data/test_database/address_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._address_1
#    creating: /content/database/spider_data/test_database/customers_card_transactions/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customers_card_transactions
#    creating: /content/database/spider_data/test_database/machine_repair/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._machine_repair
#    creating: /content/database/spider_data/test_database/real_estate_rentals/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._real_estate_rentals
#    creating: /content/database/spider_data/test_database/shop_membership/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._shop_membership
#    creating: /content/database/spider_data/test_database/wrestler/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._wrestler
#    creating: /content/database/spider_data/test_database/performance_attendance/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._performance_attendance
#    creating: /content/database/spider_data/test_database/debate/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._debate
#    creating: /content/database/spider_data/test_database/icfp_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._icfp_1
#    creating: /content/database/spider_data/test_database/e_learning/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._e_learning
#    creating: /content/database/spider_data/test_database/customer_deliveries/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customer_deliveries
#    creating: /content/database/spider_data/test_database/academic/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._academic
#    creating: /content/database/spider_data/test_database/cre_Doc_Tracking_DB/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Doc_Tracking_DB
#    creating: /content/database/spider_data/test_database/club_leader/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._club_leader
#    creating: /content/database/spider_data/test_database/art_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._art_1
#    creating: /content/database/spider_data/test_database/cre_Students_Information_Systems/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Students_Information_Systems
#    creating: /content/database/spider_data/test_database/entertainment_awards/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._entertainment_awards
#    creating: /content/database/spider_data/test_database/department_store/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._department_store
#    creating: /content/database/spider_data/test_database/customers_and_products_contacts/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customers_and_products_contacts
#    creating: /content/database/spider_data/test_database/vehicle_rent/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._vehicle_rent
#    creating: /content/database/spider_data/test_database/voter_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._voter_2
#    creating: /content/database/spider_data/test_database/bakery_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._bakery_1
#    creating: /content/database/spider_data/test_database/driving_school/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._driving_school
#    creating: /content/database/spider_data/test_database/school_finance/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._school_finance
#    creating: /content/database/spider_data/test_database/roller_coaster/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._roller_coaster
#    creating: /content/database/spider_data/test_database/journal_committee/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._journal_committee
#    creating: /content/database/spider_data/test_database/flight_4/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._flight_4
#    creating: /content/database/spider_data/test_database/club_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._club_1
#    creating: /content/database/spider_data/test_database/epinions_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._epinions_1
#    creating: /content/database/spider_data/test_database/decoration_competition/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._decoration_competition
#    creating: /content/database/spider_data/test_database/warehouse_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._warehouse_1
#    creating: /content/database/spider_data/test_database/architecture/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._architecture
#    creating: /content/database/spider_data/test_database/train_station/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._train_station
#    creating: /content/database/spider_data/test_database/allergy_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._allergy_1
#    creating: /content/database/spider_data/test_database/soccer_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._soccer_1
#    creating: /content/database/spider_data/test_database/institution_sports/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._institution_sports
#    creating: /content/database/spider_data/test_database/election_representative/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._election_representative
#    creating: /content/database/spider_data/test_database/city_record/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._city_record
#    creating: /content/database/spider_data/test_database/customers_campaigns_ecommerce/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customers_campaigns_ecommerce
#    creating: /content/database/spider_data/test_database/flight_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._flight_2
#    creating: /content/database/spider_data/test_database/poker_player/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._poker_player
#    creating: /content/database/spider_data/test_database/customer_complaints/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._customer_complaints
#    creating: /content/database/spider_data/test_database/company_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._company_1
#    creating: /content/database/spider_data/test_database/concert_singer/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._concert_singer
#    creating: /content/database/spider_data/test_database/bike_racing/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._bike_racing
#    creating: /content/database/spider_data/test_database/tv_shows/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._tv_shows
#    creating: /content/database/spider_data/test_database/cre_Docs_and_Epenses/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._cre_Docs_and_Epenses
#    creating: /content/database/spider_data/test_database/insurance_and_eClaims/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._insurance_and_eClaims
#    creating: /content/database/spider_data/test_database/insurance_policies/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._insurance_policies
#    creating: /content/database/spider_data/test_database/county_public_safety/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._county_public_safety
#    creating: /content/database/spider_data/test_database/baseball_1/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._baseball_1
#    creating: /content/database/spider_data/test_database/imdb/
#   inflating: /content/database/__MACOSX/spider_data/test_database/._imdb
#    creating: /content/database/spider_data/test_database/music_2/
#   inflating: /content/database/__MACOSX/spider_data/test_database/
#   inflating: /content/database/__MACOSX/spider_data/database/student_1/data_csv/._list.csv
#   inflating: /content/database/spider_data/database/student_1/data_csv/README.STUDENTS.TXT
#   inflating: /content/database/__MACOSX/spider_data/database/student_1/data_csv/._README.STUDENTS.TXT
#   inflating: /content/database/spider_data/database/student_1/data_csv/teachers.csv
#   inflating: /content/database/__MACOSX/spider_data/database/student_1/data_csv/._teachers.csv
#   inflating: /content/database/spider_data/database/inn_1/data_csv/Reservations.csv
#   inflating: /content/database/__MACOSX/spider_data/database/inn_1/data_csv/._Reservations.csv
#   inflating: /content/database/spider_data/database/inn_1/data_csv/Rooms.csv
#   inflating: /content/database/__MACOSX/spider_data/database/inn_1/data_csv/._Rooms.csv
#   inflating: /content/database/spider_data/database/inn_1/data_csv/Reservations_t.csv
#   inflating: /content/database/__MACOSX/spider_data/database/inn_1/data_csv/._Reservations_t.csv
#   inflating: /content/database/spider_data/database/inn_1/data_csv/README.INN.TXT
#   inflating: /content/database/__MACOSX/spider_data/database/inn_1/data_csv/._README.INN.TXT
#   inflating: /content/database/spider_data/database/twitter_1/queries/postgres-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/database/twitter_1/queries/._postgres-dialects.xml
#   inflating: /content/database/spider_data/database/twitter_1/queries/oracle-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/database/twitter_1/queries/._oracle-dialects.xml
#   inflating: /content/database/spider_data/database/twitter_1/queries/sqlserver-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/database/twitter_1/queries/._sqlserver-dialects.xml
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/circuits.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._circuits.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/status.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._status.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/drivers.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._drivers.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/driverStandings.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._driverStandings.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/races.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._races.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/constructors.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._constructors.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/constructorResults.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._constructorResults.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/lapTimes.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._lapTimes.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/qualifying.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._qualifying.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/pitStops.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._pitStops.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/seasons.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._seasons.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/constructorStandings.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._constructorStandings.csv
#   inflating: /content/database/spider_data/test_database/formula_1/data_csv/results.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/formula_1/data_csv/._results.csv
#   inflating: /content/database/spider_data/test_database/wine_1/data_csv/grapes.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/wine_1/data_csv/._grapes.csv
#   inflating: /content/database/spider_data/test_database/wine_1/data_csv/wine.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/wine_1/data_csv/._wine.csv
#   inflating: /content/database/spider_data/test_database/wine_1/data_csv/appellations.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/wine_1/data_csv/._appellations.csv
#   inflating: /content/database/spider_data/test_database/wine_1/data_csv/README.WINE.txt
#   inflating: /content/database/__MACOSX/spider_data/test_database/wine_1/data_csv/._README.WINE.txt
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/countries.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._countries.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/car-names.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._car-names.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/continents.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._continents.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/cars-data.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._cars-data.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/README.CARS.TXT
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._README.CARS.TXT
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/car-makers.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._car-makers.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/model-list.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._model-list.csv
#   inflating: /content/database/spider_data/test_database/car_1/data_csv/cars.desc
#   inflating: /content/database/__MACOSX/spider_data/test_database/car_1/data_csv/._cars.desc
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/receipts_t.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._receipts_t.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/customers.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._customers.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/items_t.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._items_t.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/receipts.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._receipts.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/receipts (3:11:18, 5:53 PM)_original.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._receipts (3:11:18, 5:53 PM)_original.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/README.BAKERY.TXT
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._README.BAKERY.TXT
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/goods.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._goods.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/goods_t.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._goods_t.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/items.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._items.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/customers_t.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._customers_t.csv
#   inflating: /content/database/spider_data/test_database/bakery_1/data_csv/items (3:11:18, 5:53 PM)_original.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/bakery_1/data_csv/._items (3:11:18, 5:53 PM)_original.csv
#   inflating: /content/database/spider_data/test_database/flight_2/data_csv/README.AIRLINES.txt
#   inflating: /content/database/__MACOSX/spider_data/test_database/flight_2/data_csv/._README.AIRLINES.txt
#   inflating: /content/database/spider_data/test_database/flight_2/data_csv/airports100.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/flight_2/data_csv/._airports100.csv
#   inflating: /content/database/spider_data/test_database/flight_2/data_csv/airlines.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/flight_2/data_csv/._airlines.csv
#   inflating: /content/database/spider_data/test_database/flight_2/data_csv/flights.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/flight_2/data_csv/._flights.csv
#   inflating: /content/database/spider_data/test_database/student_1/data_csv/list.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/student_1/data_csv/._list.csv
#   inflating: /content/database/spider_data/test_database/student_1/data_csv/README.STUDENTS.TXT
#   inflating: /content/database/__MACOSX/spider_data/test_database/student_1/data_csv/._README.STUDENTS.TXT
#   inflating: /content/database/spider_data/test_database/student_1/data_csv/teachers.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/student_1/data_csv/._teachers.csv
#   inflating: /content/database/spider_data/test_database/inn_1/data_csv/Reservations.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/inn_1/data_csv/._Reservations.csv
#   inflating: /content/database/spider_data/test_database/inn_1/data_csv/Rooms.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/inn_1/data_csv/._Rooms.csv
#   inflating: /content/database/spider_data/test_database/inn_1/data_csv/Reservations_t.csv
#   inflating: /content/database/__MACOSX/spider_data/test_database/inn_1/data_csv/._Reservations_t.csv
#   inflating: /content/database/spider_data/test_database/inn_1/data_csv/README.INN.TXT
#   inflating: /content/database/__MACOSX/spider_data/test_database/inn_1/data_csv/._README.INN.TXT
#   inflating: /content/database/spider_data/test_database/twitter_1/queries/postgres-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/test_database/twitter_1/queries/._postgres-dialects.xml
#   inflating: /content/database/spider_data/test_database/twitter_1/queries/oracle-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/test_database/twitter_1/queries/._oracle-dialects.xml
#   inflating: /content/database/spider_data/test_database/twitter_1/queries/sqlserver-dialects.xml
#   inflating: /content/database/__MACOSX/spider_data/test_database/twitter_1/queries/._sqlserver-dialects.xml

# %%
import pandas as pd
import sqlite3
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Paths to your evaluation CSVs
finetuned_csv_path = "/content/evaluation_results_FINETUNED.csv"
base_csv_path = "/content/base_evaluation_results_basemodel.csv"

# Path to the root Spider database directory
DB_ROOT = "/content/database/spider_data/test_database"

# --- Helper functions ---

def compute_bleu(reference_sql, predicted_sql):
    """Compute BLEU score between two SQL queries."""
    ref_tokens = reference_sql.strip().lower().split()
    pred_tokens = predicted_sql.strip().lower().split()
    smoothie = SmoothingFunction().method1
    return sentence_bleu([ref_tokens], pred_tokens, smoothing_function=smoothie)

def run_query(query, db_path):
    """Run SQL query on a SQLite database."""
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(query)
        results = cursor.fetchall()
        conn.close()
        return results
    except Exception as e:
        return f"ERROR: {e}"

def is_execution_match(predicted_sql, ground_truth_sql, db_path):
    try:
        return sorted(run_query(predicted_sql, db_path)) == sorted(run_query(ground_truth_sql, db_path))
    except:
        return False


def normalize_sql(query):
    """Simple SQL normalization (case-insensitive, strip semicolon)."""
    return query.strip().lower().rstrip(';')

def evaluate_file(csv_path, label):
    """Evaluate BLEU, Execution Accuracy, and Exact Match for a model output CSV."""
    df = pd.read_csv(csv_path)
    bleu_scores = []
    execution_matches = []
    exact_matches = []

    for _, row in df.iterrows():
        pred = row["predicted_sql"]
        gold = row["ground_truth_sql"]
        db_id = row["schema_prompt"].split("\n")[0].split(": ")[-1].lower()

        # BLEU score
        bleu = compute_bleu(gold, pred)
        bleu_scores.append(bleu)

        # Execution match
        db_path = f"{DB_ROOT}/{db_id}/{db_id}.sqlite"
        try:
            exec_match = is_execution_match(pred, gold, db_path)
        except Exception:
            exec_match = False
        execution_matches.append(exec_match)

        # Exact match
        norm_pred = normalize_sql(pred)
        norm_gold = normalize_sql(gold)
        exact_matches.append(norm_pred == norm_gold)

    df["bleu_score"] = bleu_scores
    df["execution_match"] = execution_matches
    df["exact_match"] = exact_matches

    avg_bleu = round(df["bleu_score"].mean(), 4)
    exec_acc = round(df["execution_match"].mean(), 4)
    exact_acc = round(df["exact_match"].mean(), 4)

    return label, avg_bleu, exec_acc, exact_acc

# --- Run evaluation on both models ---

f_label, f_bleu, f_exec, f_exact = evaluate_file(finetuned_csv_path, "Finetuned Model")
b_label, b_bleu, b_exec, b_exact = evaluate_file(base_csv_path, "Base Model")

# --- Show comparison ---

comparison_df = pd.DataFrame({
    "Metric": ["Average BLEU Score", "Execution Accuracy", "Exact Match Accuracy"],
    f_label: [f_bleu, f_exec, f_exact],
    b_label: [b_bleu, b_exec, b_exact]
})

from IPython.display import display
display(comparison_df)
# Out:
#                  Metric  Finetuned Model  Base Model
# 0    Average BLEU Score           0.7031      0.1444
# 1    Execution Accuracy           1.0000      1.0000
# 2  Exact Match Accuracy           0.4700      0.0200

# %% [markdown]
# # Inference

# %%
from openai import OpenAI
import pandas as pd
from getpass import getpass
import json

# Prompt for API key securely
api_key = getpass("Enter your OpenAI API key: ")
client = OpenAI(api_key=api_key)

# Model IDs
BASE_MODEL = "gpt-4o-mini-2024-07-18"
FINETUNED_MODEL = "ft:gpt-4o-mini-2024-07-18:sjsu::BV5M5MaD"

# Path to Spider schema info
TABLES_PATH = "/content/database/spider_data/tables.json"

# Load Spider validation questions
from datasets import load_dataset
questions = load_dataset("spider")["validation"]

# Load tables.json for schema prompts
with open(TABLES_PATH, 'r') as f:
    tables_data = json.load(f)

def get_schema_prompt(db_id):
    for table in tables_data:
        if table["db_id"] == db_id:
            schema_lines = []
            for i, table_name in enumerate(table["table_names_original"]):
                cols = [col[1] for col in table["column_names_original"] if col[0] == i]
                schema_lines.append(f"Table: {table_name}")
                schema_lines.append("Columns: " + ", ".join(cols))
            return "\n".join(schema_lines)
    return "Schema not found."

# Generate SQL for a question using a specific model
def generate_sql(model_id, question, schema_prompt):
    try:
        response = client.chat.completions.create(
            model=model_id,
            messages=[
                {"role": "system", "content": f"You are a SQL generator. Given a question and a schema, generate SQL.\n\n{schema_prompt}"},
                {"role": "user", "content": question}
            ],
            temperature=0.0,
            max_tokens=200
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"ERROR: {e}"

# Run inference on N examples
N = 10
results = []

for item in questions.select(range(N)):
    q = item["question"]
    db_id = item["db_id"]
    ground_truth = item["query"]
    schema_prompt = get_schema_prompt(db_id)

    base_pred = generate_sql(BASE_MODEL, q, schema_prompt)
    finetuned_pred = generate_sql(FINETUNED_MODEL, q, schema_prompt)

    results.append({
        "question": q,
        "ground_truth": ground_truth,
        "base_model_prediction": base_pred,
        "finetuned_model_prediction": finetuned_pred
    })

# Convert to DataFrame
df = pd.DataFrame(results)
from IPython.display import display
display(df)
# Out:
# Enter your OpenAI API key: ··········
#                                             question  \
# 0                       How many singers do we have?
# 1               What is the total number of singers?
# 2  Show name, country, age for all singers ordere...
# 3  What are the names, countries, and ages for ev...
# 4  What is the average, minimum, and maximum age ...
# 5  What is the average, minimum, and maximum age ...
# 6  Show the name and the release year of the song...
# 7  What are the names and release years for all t...
# 8  What are all distinct countries where singers ...
# 9  What are  the different countries with singers...
#
#                                         ground_truth  \
# 0                        SELECT count(*) FROM singer
# 1                        SELECT count(*) FROM singer
# 2  SELECT name ,  country ,  age FROM singer ORDE...
# 3  SELECT name ,  country ,  age FROM singer ORDE...
# 4  SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# 5  SELECT avg(age) ,  min(age) ,  max(age) FROM s...
# 6  SELECT song_name ,  song_release_year FROM sin...
# 7  SELECT song_name ,  song_release_year FROM sin...
# 8  SELECT DISTINCT country FROM singer WHERE age ...
# 9  SELECT DISTINCT country FROM singer WHERE age ...
#
#                                base_model_prediction  \
# 0  ```sql\nSELECT COUNT(*) AS NumberOfSingers\nFR...
# 1  ```sql\nSELECT COUNT(*) AS total_singers\nFROM...
# 2  ```sql\nSELECT Name, Country, Age\nFROM singer...
# 3  ```sql\nSELECT Name, Country, Age\nFROM singer...
# 4  ```sql\nSELECT \n    AVG(Age) AS Average_Age, ...
# 5  ```sql\nSELECT \n    AVG(Age) AS Average_Age, ...
# 6  ```sql\nSELECT s.Song_Name, s.Song_release_yea...
# 7  To find the names and release years for all th...
# 8  ```sql\nSELECT DISTINCT Country\nFROM singer\n...
# 9  ```sql\nSELECT DISTINCT Country\nFROM singer\n...
#
#                           finetuned_model_prediction
# 0                        select count(*) from singer
# 1                        select count(*) from singer
# 2  ```sql\nSELECT Name, Country, Age FROM singer ...
# 3  select name ,  country ,  age from singer orde...
# 4  select avg(age) ,  min(age) ,  max(age) from s...
# 5  select avg(age) ,  min(age) ,  max(age) from s...
# 6  select T2.Name ,  T2.Song_release_year from si...
# 7  To find the names and release years for all th...
# 8  ```sql\nSELECT DISTINCT Country FROM singer WH...
# 9  select distinct country from singer where age ...

# %%
from graphviz import Digraph

dot = Digraph(comment='Agentic Approach')

# Nodes
dot.node('NL', 'Natural Language Query')
dot.node('QU', 'Query Understanding')
dot.node('AD', 'Ambiguity Detection')
dot.node('CD', 'Clarification Dialogue')
dot.node('SP', 'SQL Planning')
dot.node('UU', 'Updated Understanding')
dot.node('SG', 'SQL Generation')
dot.node('EX', 'Execution')
dot.node('RS', 'Results')
dot.node('VS', 'Visualization Selection')

# Edges
dot.edge('NL', 'QU')
dot.edge('QU', 'AD')
dot.edge('AD', 'CD', label='If ambiguous')
dot.edge('AD', 'SP', label='If clear')
dot.edge('CD', 'UU')
dot.edge('UU', 'SG')
dot.edge('SP', 'SG')
dot.edge('SG', 'EX')
dot.edge('EX', 'RS')
dot.edge('RS', 'VS')

# Render (optional)
dot.render('agentic_approach_diagram', format='png', cleanup=True)

# To display in Jupyter or Streamlit
dot.view()
# Out:
# 'agentic_approach_diagram.pdf'

# %%
from graphviz import Digraph

dot = Digraph('AgenticApproach', format='png')
dot.attr(rankdir='LR', size='10')

# Style for nodes
dot.attr('node', shape='box', style='filled', color='lightgray', fontsize='12')

# Main path
dot.node('NLQ', 'Natural Language Query')
dot.node('QU', 'Query Understanding')
dot.node('AD', 'Ambiguity Detection')
dot.node('SP', 'SQL Planning')
dot.node('SG', 'SQL Generation')
dot.node('EX', 'Execution')
dot.node('RES', 'Results')
dot.node('VIS', 'Visualization Selection')

# Clarification path
dot.node('CD', 'Clarification Dialogue')
dot.node('UU', 'Updated Understanding')

# Main edges
dot.edge('NLQ', 'QU')
dot.edge('QU', 'AD')
dot.edge('AD', 'SP', label='Clear')
dot.edge('SP', 'SG')
dot.edge('SG', 'EX')
dot.edge('EX', 'RES')
dot.edge('RES', 'VIS')

# Clarification branch
dot.edge('AD', 'CD', label='Ambiguous')
dot.edge('CD', 'UU')
dot.edge('UU', 'SG')

# Output to file (optional)
dot.render('agentic_approach_clean', view=True)
# Out:
# 'agentic_approach_clean.png'

# %%
from graphviz import Digraph

dot = Digraph('AgenticApproach', format='png')
dot.attr(rankdir='TB', size='8')

# Node styles
dot.attr('node', style='filled', fontsize='12', fontname='Helvetica')

# Start and end nodes (rounded)
dot.node('NL', 'Natural Language Query', shape='ellipse', color='lightblue')
dot.node('VS', 'Visualization Selection', shape='ellipse', color='lightblue')

# Regular processing steps (rectangles)
dot.node('QU', 'Query Understanding', shape='box', color='lightgrey')
dot.node('CD', 'Clarification Dialogue', shape='box', color='lightyellow')
dot.node('UU', 'Updated Understanding', shape='box', color='lightgrey')
dot.node('SP', 'SQL Planning', shape='box', color='lightgrey')
dot.node('SG', 'SQL Generation', shape='box', color='lightgrey')
dot.node('EX', 'Execution', shape='box', color='lightgrey')
dot.node('RS', 'Results', shape='box', color='lightgreen')

# Decision node (diamond)
dot.node('AD', 'Ambiguity Detected?', shape='diamond', color='orange')

# Edges (flow)
dot.edge('NL', 'QU')
dot.edge('QU', 'AD')
dot.edge('AD', 'CD', label='Yes')
dot.edge('AD', 'SP', label='No')
dot.edge('CD', 'UU')
dot.edge('UU', 'SG')
dot.edge('SP', 'SG')
dot.edge('SG', 'EX')
dot.edge('EX', 'RS')
dot.edge('RS', 'VS')

# Render and optionally view
dot.render('agentic_approach_final', view=True)
# Out:
# 'agentic_approach_final.png'

# %%
from graphviz import Digraph

dot = Digraph('AgenticApproach', format='png')
dot.attr(rankdir='LR', size='10')

# Node styles
dot.attr('node', style='filled', fontsize='12', fontname='Helvetica')

# Start/end nodes (rounded, light blue)
dot.node('NL', 'Natural Language Query', shape='ellipse', color='lightblue')
dot.node('VS', 'Visualization\nSelection', shape='ellipse', color='lightblue')

# Regular processing (rectangles)
dot.node('QU', 'Query\nUnderstanding', shape='box', color='lightgrey')
dot.node('CD', 'Clarification\nDialogue', shape='box', color='lightyellow')
dot.node('UU', 'Updated\nUnderstanding', shape='box', color='lightgrey')
dot.node('SP', 'SQL\nPlanning', shape='box', color='lightgrey')
dot.node('SG', 'SQL\nGeneration', shape='box', color='lightgrey')
dot.node('EX', 'Execution', shape='box', color='lightgrey')
dot.node('RS', 'Results', shape='box', color='lightgreen')

# Decision node (diamond, orange)
dot.node('AD', 'Ambiguity\nDetected?', shape='diamond', color='orange')

# Flow edges
dot.edge('NL', 'QU')
dot.edge('QU', 'AD')
dot.edge('AD', 'CD', label='Yes')
dot.edge('AD', 'SP', label='No')
dot.edge('CD', 'UU')
dot.edge('UU', 'SG')
dot.edge('SP', 'SG')
dot.edge('SG', 'EX')
dot.edge('EX', 'RS')
dot.edge('RS', 'VS')

# Render and view
dot.render('agentic_approach_horizontal', view=True)
# Out:
# 'agentic_approach_horizontal.png'

# %%
from graphviz import Digraph

dot = Digraph('AgenticApproach', format='png')
dot.attr(rankdir='LR', size='12,8', nodesep='1.0', ranksep='1.5')

# Global node style
dot.attr('node', style='filled', fontsize='12', fontname='Helvetica', width='2', height='1')

# Rounded start/end nodes
dot.node('NL', 'Natural Language\nQuery', shape='ellipse', color='lightblue')
dot.node('VS', 'Visualization\nSelection', shape='ellipse', color='lightblue')

# Processing steps (rectangular)
dot.node('QU', 'Query\nUnderstanding', shape='box', color='lightgrey')
dot.node('CD', 'Clarification\nDialogue', shape='box', color='lightyellow')
dot.node('UU', 'Updated\nUnderstanding', shape='box', color='lightgrey')
dot.node('SP', 'SQL\nPlanning', shape='box', color='lightgrey')
dot.node('SG', 'SQL\nGeneration', shape='box', color='lightgrey')
dot.node('EX', 'Execution', shape='box', color='lightgrey')
dot.node('RS', 'Results', shape='box', color='lightgreen')

# Decision node (diamond)
dot.node('AD', 'Ambiguity\nDetected?', shape='diamond', color='orange')

# Edges (flow)
dot.edge('NL', 'QU')
dot.edge('QU', 'AD')
dot.edge('AD', 'CD', label='Yes')
dot.edge('AD', 'SP', label='No')
dot.edge('CD', 'UU')
dot.edge('UU', 'SG')
dot.edge('SP', 'SG')
dot.edge('SG', 'EX')
dot.edge('EX', 'RS')
dot.edge('RS', 'VS')

# Render
dot.render('agentic_approach_balanced_horizontal', view=True)
# Out:
# 'agentic_approach_balanced_horizontal.png'
